# %% [markdown]
# Load the reviews

# %%
import utils.wordnet as wordnet

data_raw = 'data/raw'
docs = wordnet.load_reviews(data_raw)
# Out:
# The number of businesses: 2051

# %% [markdown]
# Process through all the documents

# %%
# Show without saving
wc = WCloud(docs)
wc.process(bid='JB8-8TtNYX-vLqN7cz-zHA')
wc.draw(show=True)

# %%
# No show(only save)
wc = WCloud(docs)
wc.process(bid='JB8-8TtNYX-vLqN7cz-zHA')
wc.draw(show=False)

# %% [markdown]
# Visualize using Networks

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

wn.draw(k = 5)

# %% [markdown]
# Analyze for multiple keywords

# %%
wordnets = dict()
keywords = ['price','taste']
for keyword in keywords:
    wn = wordnet.WordNet(keyword)
    for sent in wordnet.dociterator(docs):
        wn(sent)
    wordnets[keyword] = wn
# Out:
# Processing the document #0
# Processing the document #1000
# Processing the document #2000
# Processing the document #0
# Processing the document #1000
# Processing the document #2000

# %%
for keyword, wn in wordnets.items():
    plt.figure()
    wn.draw(k = 5)
    plt.show()
