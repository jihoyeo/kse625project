# %% [markdown]
# # Unconditional sampling

# %%
from utils.preprocess import JSONLoader
                        
business = 'business.json'
review = 'review.json'
user = 'user.json'
data_dir = 'data/dataset'

# Sample 100 entries from each json files
fields = ['business_id','stars']
f_b, json_b = JSONLoader(business, data_dir, fields = fields).sample(100)
f_r, json_r = JSONLoader(review, data_dir).sample(100)
f_u, json_u = JSONLoader(user, data_dir).sample(100)

# %%
json_b
# Out:
# [['YDf95gJZaq05wvo7hTQbbQ', 2.0],
#  ['mLwM-h2YhXl2NCgdS84_Bw', 4.5],
#  ['v2WhjAB3PIBA8J8VxG3wEg', 4.5],
#  ['CVtCbSB1zUcUWg-9TNGTuQ', 3.0],
#  ['duHFBe87uNSXImQmvBh87Q', 4.5],
#  ['uUEMrhJiL1a1pCA_I1SU7Q', 5.0],
#  ['2eJEUJIP54tex7T9YOcLSw', 5.0],
#  ['fEylCY3UEH8YJ0Xa7lu6lA', 2.5],
#  ['kFtuYklkAIlmYw8RZAieGw', 5.0],
#  ['NqiQdFa93wzUJGo29NbTPQ', 5.0],
#  ['N9BN9ldVl1FNzcB9_eAstw', 4.5],
#  ['6s3z3TlpHOIecuSyPEOp7A', 4.5],
#  ['n33Izvzk_z9_51H6NsQF-A', 2.0],
#  ['m06OZRFTaKKi6U0omfLq4g', 4.5],
#  ['SDMRxmcKPNt1AHPBKqO64Q', 2.0],
#  ['iFEiMJoEqyB9O8OUNSdLzA', 3.0],
#  ['qrAHt4wWRYWj1sEjxq574A', 3.5],
#  ['jqp5TibmgJZVFKHTp3XfqQ', 3.0],
#  ['1cLXGXThDYZ5WK_KpBLtkw', 4.0],
#  ['BmSJ6C7Y9s3tHotRetVbmA', 3.5],
#  ['Av-ODv7-hV12If005Pj6wA', 3.0],
#  ['HmI9nhgOkrXlUr6KZGZZew', 3.0],
#  ['qnpvw-uQyRn9nlClWFK9aA', 2.5],
#  ['igcy3ojJbgbpS8K70gvFQg', 5.0],
#  ['5Ghe0btvM7tXqANnhNB5eg', 5.0],
#  ['vvB8ebrUsjfNqwWjk4G4OQ', 4.0],
#  ['l9ABoPi9j_pH9588tk0-6w', 4.0],
#  ['eW9vw2fE_6EuTWErZRo3mQ', 4.0],
#  ['ZFGYEsHFo6G4KtlTpYmMRQ', 3.5],
#  ['ATsUb_sLzDSZkIoBdoO_mg', 3.5],
#  ['-PtTGvWsckUL8tTutHr6Ew', 2.5],
#  ['TXiEgINSZ75d3EtvLvkc4Q', 3.0],
#  ['KW4y7uDGjVfU3ClkEjIGhg', 3.0],
#  ['s_6WYPw3t50el2fSuh9k8w', 4.5],
#  ['reWc1g65PNZnKz_Ub9QKOQ', 2.5],
#  ['L1XHTn7S-6har9UGAPjcWQ', 4.0],
#  ['PV9CdNFDOX4_zWm3Sy3W8g', 3.0],
#  ['8E5l83iGubQmtivb24TL_Q', 3.0],
#  ['qim0lD112TkDhm8ZyQlRnA', 4.0],
#  ['xmY0pzNvZKEzuN0XEqeV5w', 4.5],
#  ['aj1C0D7hniEPpsTidbCQIg', 5.0],
#  ['9tIYh_c2Yynt2N65epRJ1w', 3.0],
#  ['HRFJlSAP_EBU_MpPPmpUDQ', 2.5],
#  ['5-7EItFT0a7SOlpjwE39_g', 2.5],
#  ['kEq7eudoX5qdcaSLAq3axw', 3.0],
#  ['UZShf6G75npKCCjiHsf46Q', 3.5],
#  ['4irpCt5a5Sa72kIGyTmJ1Q', 3.5],
#  ['KhPCS4OAr9po5hMtFhDvmg', 3.5],
#  ['45arahaS6jTtYBw_STLDXg', 2.5],
#  ['L2fkc0j8rkEXc1bMO8-uGQ', 4.5],
#  ['FLTbKRmBytP1AbjWSPEeyw', 4.0],
#  ['1AxEmgv8Dsr3iU9Aa40jPw', 4.0],
#  ['LLNmo66wO1xoi-yma1HybA', 3.0],
#  ['Wf5C8Amv_SlhoYE3_W66WQ', 2.0],
#  ['58APdML-PG_OD4El2ePTvw', 4.0],
#  ['Z1r6b30Tg0n0ME4-Zj2wQQ', 3.0],
#  ['-2q4dnUw0gGJniGW2aPamQ', 2.0],
#  ['6WMSw48PHoHboOG33R8OJw', 1.5],
#  ['LDMCrFlGIFUN6L-FEFgzWg', 3.0],
#  ['cBHMUESPj4SNs65Xv6xWRA', 4.0],
#  ['uG4YxC4OA0bg6S_Yko2pMg', 1.5],
#  ['EvX3LA7Wc1tv1S4qrendxQ', 4.5],
#  ['g2FSpf4OTWcQauAOWjoL-g', 3.5],
#  ['v86J4q6ATA2ANm1fc7yCNg', 3.5],
#  ['QTH_XGh4rWYdd0fTW-tUDw', 3.5],
#  ['ghDBE0fCjRfj7_fLoXnICw', 3.5],
#  ['gqv6zoGHSeTsNKynhjI-Ng', 3.5],
#  ['ynN2PeYIpufc_eSjE2Rtbg', 4.0],
#  ['g-HSA1m2vFPjKHYnqiL6qA', 5.0],
#  ['WKPnq7NYw4IV5IG2smpd1Q', 3.0],
#  ['01xXe2m_z048W5gcBFpoJA', 3.5],
#  ['dEmNOTm8Rmm9JYZdGX_Lhw', 4.0],
#  ['3J75SkvgoLikY5Z4znmHjw', 4.0],
#  ['efftalgKFDTs9itqHbVttg', 4.0],
#  ['VoHZ4U8gvY33BxXtcsy5Rw', 3.5],
#  ['fIWozPW-2wRknzsDqdgyjg', 5.0],
#  ['UlDvngOADDhshzMKvrMsQw', 5.0],
#  ['VrYc4SGCGXFxlNZNrwS39w', 4.5],
#  ['SnlaPHqW3ksKfpH12pDGeg', 3.5],
#  ['Bl7Y-ATTzXytQnCceg5k6w', 3.0],
#  ['BvCHyg0GtxA6XKmRC0cQsg', 4.0],
#  ['BwNZaPoqjHYK4RMqAxSeCw', 3.5],
#  ['fl2TPNWrchkCbNEg0utjvw', 2.0],
#  ['MKT77UstJ5PAWyLNTuWujQ', 3.0],
#  ['CD_ExwWCwGjxWYagfDBnbw', 4.5],
#  ['tzHbcCa6wMyNgQD0zqaQJA', 5.0],
#  ['b5VIe-VnkOOwiwkjGw071A', 4.0],
#  ['vfn-BKoMtOG6bf-QoU5b6Q', 2.0],
#  ['9TfpnjAKFtP1u3C3eIFQ5Q', 4.5],
#  ['IVtp8mznb2vRO0OcwBEQMw', 4.5],
#  ['DiA78qPtp6rfRNdomzjBbw', 3.5],
#  ['voF2F6emy4zrDAezPC6bkg', 5.0],
#  ['SPdAkTJkQ_roC4dF4bvNpw', 4.5],
#  ['25lVJgvthMyvoRz-W6splw', 2.0],
#  ['ldwon-7FnBRRblX8RirnEg', 3.5],
#  ['IxUKeZlUE-sGTQMKErvrJg', 4.0],
#  ['GoVRPbvG9oLfNZ54v4nYbw', 3.5],
#  ['z9lq1goS0IRqeIIUEZA4Pg', 4.5],
#  ['d2fkRF67jiASrXxHfbmJuA', 2.5],
#  ['weXoqWqLgzMOf5Yz-qiujw', 3.0]]

# %% [markdown]
# # Conditional sampling

# %%
fields = ['business_id','stars','categories']
city = ['Toronto']
categories =['Restaurants', 'Food', 'Sandwiches', 'Fast Food', 'American (Traditional)', 'Pizza',
                 'Italian', 'Burgers', 'Mexican','Breakfast & Brunch', 'American (New)', 'Chinese', 'Specialty Food', 'Bakeries', 'Desserts',
                 'Japanese', 'Ice Cream & Frozen Yogurt', 'Chicken Wings, Seafood', 'Salad', 'Sushi Bars',
                 'Asian Fusion', 'Thai', 'Indian']

business = 'business.json'
data_dir = 'data/dataset'
jl = JSONLoader(business, data_dir, fields = fields)
jl.set_condition(city=city, categories=categories)
f_b, json_b = jl.sample(1000)

# %%
json_b
# Out:
# [['mLwM-h2YhXl2NCgdS84_Bw',
#   4.5,
#   ['Food', 'Soul Food', 'Convenience Stores', 'Restaurants']],
#  ['v2WhjAB3PIBA8J8VxG3wEg', 4.5, ['Food', 'Coffee & Tea']],
#  ['duHFBe87uNSXImQmvBh87Q', 4.5, ['Sandwiches', 'Restaurants']],
#  ['n33Izvzk_z9_51H6NsQF-A',
#   2.0,
#   ['Flowers & Gifts', 'Bakeries', 'Grocery', 'Shopping', 'Food', 'Florists']],
#  ['SDMRxmcKPNt1AHPBKqO64Q',
#   2.0,
#   ['Burgers',
#    'Bars',
#    'Restaurants',
#    'Sports Bars',
#    'Nightlife',
#    'American (Traditional)']],
#  ['iFEiMJoEqyB9O8OUNSdLzA', 3.0, ['Chinese', 'Restaurants']],
#  ['1cLXGXThDYZ5WK_KpBLtkw', 4.0, ['Food', 'Bakeries', 'Coffee & Tea']],
#  ['HmI9nhgOkrXlUr6KZGZZew',
#   3.0,
#   ['Sandwiches',
#    'Restaurants',
#    'Italian',
#    'Diners',
#    'Breakfast & Brunch',
#    'Mexican']],
#  ['qnpvw-uQyRn9nlClWFK9aA', 2.5, ['Chicken Wings', 'Restaurants']],
#  ['TXiEgINSZ75d3EtvLvkc4Q',
#   3.0,
#   ['Restaurants', 'Seafood', 'American (Traditional)']],
#  ['KW4y7uDGjVfU3ClkEjIGhg', 3.0, ['Burgers', 'Restaurants']],
#  ['reWc1g65PNZnKz_Ub9QKOQ',
#   2.5,
#   ['Comfort Food',
#    'Canadian (New)',
#    'Restaurants',
#    'Bars',
#    'Nightlife',
#    'American (Traditional)']],
#  ['L1XHTn7S-6har9UGAPjcWQ',
#   4.0,
#   ['Taiwanese', 'Food', 'Coffee & Tea', 'Restaurants']],
#  ['PV9CdNFDOX4_zWm3Sy3W8g',
#   3.0,
#   ['Burgers',
#    'Chicken Wings',
#    'Bars',
#    'Restaurants',
#    'American (Traditional)',
#    'Nightlife']],
#  ['qim0lD112TkDhm8ZyQlRnA',
#   4.0,
#   ['Pubs', 'Restaurants', 'Bars', 'Irish', 'Nightlife']],
#  ['HRFJlSAP_EBU_MpPPmpUDQ',
#   2.5,
#   ['Chicken Wings', 'Sandwiches', 'Restaurants', 'Pizza']],
#  ['kEq7eudoX5qdcaSLAq3axw', 3.0, ['Bakeries', 'Food']],
#  ['UZShf6G75npKCCjiHsf46Q', 3.5, ['Food', 'Grocery']],
#  ['FLTbKRmBytP1AbjWSPEeyw', 4.0, ['Restaurants', 'Chinese']],
#  ['1AxEmgv8Dsr3iU9Aa40jPw', 4.0, ['Nightlife', 'Restaurants', 'Bars']],
#  ['LLNmo66wO1xoi-yma1HybA', 3.0, ['Bars', 'Pubs', 'Nightlife', 'Food']],
#  ['Wf5C8Amv_SlhoYE3_W66WQ',
#   2.0,
#   ['Asian Fusion', 'Restaurants', 'Sushi Bars']],
#  ['58APdML-PG_OD4El2ePTvw',
#   4.0,
#   ['Restaurants',
#    'Specialty Food',
#    'French',
#    'Breakfast & Brunch',
#    'Food',
#    'Delicatessen']],
#  ['Z1r6b30Tg0n0ME4-Zj2wQQ',
#   3.0,
#   ['American (Traditional)',
#    'Restaurants',
#    'Bars',
#    'Pubs',
#    'Beer',
#    'Wine & Spirits',
#    'Food',
#    'Nightlife']],
#  ['-2q4dnUw0gGJniGW2aPamQ', 2.0, ['Restaurants', 'Mexican']],
#  ['LDMCrFlGIFUN6L-FEFgzWg',
#   3.0,
#   ['Restaurants', 'American (Traditional)', 'Mexican', 'Fast Food']],
#  ['cBHMUESPj4SNs65Xv6xWRA',
#   4.0,
#   ['Food',
#    'Shopping',
#    'Grocery',
#    'Delis',
#    'Gift Shops',
#    'Coffee & Tea',
#    'Flowers & Gifts',
#    'Restaurants']],
#  ['uG4YxC4OA0bg6S_Yko2pMg', 1.5, ['Food', 'Donuts']],
#  ['v86J4q6ATA2ANm1fc7yCNg',
#   3.5,
#   ['Nightlife', 'Lounges', 'Beer', 'Wine & Spirits', 'Bars', 'Food']],
#  ['QTH_XGh4rWYdd0fTW-tUDw', 3.5, ['Mexican', 'Restaurants']],
#  ['01xXe2m_z048W5gcBFpoJA',
#   3.5,
#   ['American (New)', 'Burgers', 'Fast Food', 'Restaurants']],
#  ['dEmNOTm8Rmm9JYZdGX_Lhw', 4.0, ['Italian', 'Restaurants']],
#  ['Bl7Y-ATTzXytQnCceg5k6w',
#   3.0,
#   ['American (Traditional)', 'Breakfast & Brunch', 'Restaurants']],
#  ['BvCHyg0GtxA6XKmRC0cQsg', 4.0, ['Pizza', 'Restaurants']],
#  ['fl2TPNWrchkCbNEg0utjvw',
#   2.0,
#   ['Diners',
#    'Breakfast & Brunch',
#    'Burgers',
#    'American (New)',
#    'Ice Cream & Frozen Yogurt',
#    'Fast Food',
#    'Restaurants',
#    'Food']],
#  ['MKT77UstJ5PAWyLNTuWujQ', 3.0, ['Bakeries', 'Desserts', 'Cupcakes', 'Food']],
#  ['CD_ExwWCwGjxWYagfDBnbw',
#   4.5,
#   ['Candy Stores', 'Popcorn Shops', 'Desserts', 'Food', 'Specialty Food']],
#  ['b5VIe-VnkOOwiwkjGw071A', 4.0, ['Chinese', 'Restaurants']],
#  ['DiA78qPtp6rfRNdomzjBbw',
#   3.5,
#   ['Chinese', 'Food', 'Convenience Stores', 'Restaurants']],
#  ['d2fkRF67jiASrXxHfbmJuA', 2.5, ['Restaurants', 'Chinese']],
#  ['weXoqWqLgzMOf5Yz-qiujw', 3.0, ['Italian', 'Restaurants', 'Pizza']],
#  ['wsyNO9Ac4gqGYTBfNeM1VA', 4.5, ['Mexican', 'Restaurants']],
#  ['lhryYODlAmzQLZGkwmZ8wA', 3.5, ['Fast Food', 'Chinese', 'Restaurants']],
#  ['JA-WeSdtaFagoI6doN0Sbw',
#   4.5,
#   ['Ice Cream & Frozen Yogurt', 'Food', 'Cupcakes']],
#  ['YTqtM2WFhcMZGeAGA08Cfg',
#   4.5,
#   ['Seafood',
#    'Restaurants',
#    'Specialty Food',
#    'Ethnic Food',
#    'Food',
#    'Mexican']],
#  ['8gzRJEmYJGTCdahRKcafXw',
#   2.5,
#   ['Restaurants', 'Food', 'Tea Rooms', 'Chinese']],
#  ['3HfRVRP7dWzOzrfbZmzk-Q', 3.5, ['Food']],
#  ['FQCKnbmIPlg2NNq4KBSBzg',
#   4.5,
#   ['Shaved Ice',
#    'Food',
#    'Desserts',
#    'Ice Cream & Frozen Yogurt',
#    'Juice Bars & Smoothies']],
#  ['aBGT2NQ9fSesoB93-eVj5w',
#   2.0,
#   ['Food',
#    'Shopping',
#    'Photography Stores & Services',
#    'Beauty & Spas',
#    'Cosmetics & Beauty Supply',
#    'Drugstores',
#    'Convenience Stores']],
#  ['Oto60yDwk1z72WmfWEYrjg', 3.0, ['Food', 'Restaurants', 'Mexican']],
#  ['EQEjBxW64QzleZHvRYA31A', 4.0, ['Coffee & Tea', 'Bakeries', 'Food']],
#  ['5GJ60TyviQnyg2257CAGuA',
#   4.5,
#   ['Restaurants', 'Waffles', 'Sandwiches', 'Delis']],
#  ['wJY74R0zAgjxvBf-d4gm9g', 3.5, ['American (New)', 'Restaurants']],
#  ['iMoFE2g4kDG4FfKLJvk3Jw', 4.0, ['Restaurants', 'Korean']],
#  ['7HFRdxVttyY9GiMpywhhYw',
#   3.0,
#   ['Pizza',
#    'Caterers',
#    'Italian',
#    'Wraps',
#    'Event Planning & Services',
#    'Restaurants']],
#  ['G7QZWVm-ytyKHpvUq3ggFA', 3.0, ['Restaurants', 'Pizza']],
#  ['0u2xwNy07-z3gv0tpuJX2Q', 3.5, ['Fast Food', 'Restaurants', 'Sandwiches']],
#  ['oMcKvfNGX2HleFxYg1VGqg', 2.0, ['Italian', 'Restaurants']],
#  ['Q4go7pt_ygwzXLME7kW10Q', 3.0, ['Bars', 'Pubs', 'Restaurants', 'Nightlife']],
#  ['ZPVhjltJcQ-YnaoV-h-FeA', 4.0, ['Italian', 'Restaurants']],
#  ['XuLXX5B5W1P-iNpgXmqmjQ', 2.0, ['Fast Food', 'Sandwiches', 'Restaurants']],
#  ['SRg6VOJLidr8Pw-ImaalQg',
#   4.0,
#   ['Juice Bars & Smoothies', 'Food', 'Vegetarian', 'Restaurants']],
#  ['-K4gAv8_vjx8-2BxkVeRkA', 3.5, ['Bakeries', 'Food']],
#  ['I891YJPgiL7lENaEz8sdqw', 4.5, ['Restaurants', 'Italian', 'Food']],
#  ['KTai0Sc45p4A-j2RYoDnHQ', 4.0, ['Restaurants', 'Pizza']],
#  ['sIZm6SbTVueFfswzo-a0hg', 3.5, ['Tex-Mex', 'Mexican', 'Restaurants']],
#  ['WogsxjRhg-HptXIPGkWMfw',
#   4.0,
#   ['Beer',
#    'Wine & Spirits',
#    'Food',
#    'Swabian',
#    'Bars',
#    'Wine Bars',
#    'Restaurants',
#    'Nightlife']],
#  ['kLw_FmSiEqYH-MtFhDIUFQ', 3.5, ['Cajun/Creole', 'Restaurants', 'Seafood']],
#  ['71YhxOJlTEch0q5gmjKfHw', 4.0, ['Food', 'Beer', 'Wine & Spirits']],
#  ['uYYXLcDNQhgUIQcfauaKrw', 3.0, ['Sandwiches', 'Restaurants']],
#  ['KXl2k4LkrmnHRTTAY-TVDQ', 3.5, ['Restaurants', 'Asian Fusion', 'Indian']],
#  ['Er8lBoKdYofhheu0Di93fw', 4.0, ['Restaurants', 'Canadian (New)']],
#  ['y9cMrm4_ZSsbH00NATButQ',
#   4.5,
#   ['Caterers', 'Chicken Wings', 'Restaurants', 'Event Planning & Services']],
#  ['lXcxSdPa2m__LqhsaL9t9A',
#   3.5,
#   ['Restaurants', 'Sandwiches', 'Delis', 'Fast Food']],
#  ['8Rdz0VPY8CuT2GQZ7ho2sw', 4.5, ['Restaurants', 'Japanese', 'Sushi Bars']],
#  ['DAMTCTsSeACXbkSABkhZqQ', 3.5, ['Pizza', 'Sandwiches', 'Restaurants']],
#  ['Pawavw9U8rjxWVPU-RB7LA', 3.5, ['Chinese', 'Restaurants']],
#  ['0e-j5VcEn54EZT-FKCUZdw',
#   4.5,
#   ['Sushi Bars', 'Restaurants', 'Japanese', 'Korean']],
#  ['zcWit_aSGR5wiunYB_Zapw',
#   4.0,
#   ['Juice Bars & Smoothies', 'Desserts', 'Coffee & Tea', 'Food']],
#  ['aP2Ma-Wx2lydppntCGhNSg', 3.5, ['Mexican', 'Restaurants', 'Barbeque']],
#  ['rjGL3G1dBQfkrQJgitMCaw', 5.0, ['Restaurants', 'Cafes']],
#  ['RzVHK8Jfcy8RvXjn_z3OBw', 4.0, ['Restaurants', 'Pizza']],
#  ['BCzZbgOjJFexYbGfSd6UZg', 2.5, ['Burgers', 'Restaurants', 'Hot Dogs']],
#  ['sQtuhDHk4RhA2lJwOxY8hQ', 2.0, ['Restaurants', 'Sushi Bars']],
#  ['FTlDoGvZ2KFdjDKxvHA8cg',
#   1.5,
#   ['Food', 'Chocolatiers & Shops', 'Specialty Food']],
#  ['_IeVVmUIO8R3_nS-88A9AA',
#   4.5,
#   ['Canadian (New)', 'Restaurants', 'Caribbean']],
#  ['er56AAp9r8mEJBAhaG02Xg',
#   4.5,
#   ['Bars',
#    'Lounges',
#    'Cajun/Creole',
#    'Caribbean',
#    'American (New)',
#    'Nightlife',
#    'Restaurants']],
#  ['TeUlBlNYodKBtcL-zc-4pA', 4.5, ['Restaurants', 'French']],
#  ['Uyh4JZ0T3nbpBWzm1xrABw', 3.5, ['Barbeque', 'Restaurants']],
#  ['o-0Nen1h78jiWZF_Aq_Jmg',
#   3.5,
#   ['Food', 'Distilleries', 'Arts & Entertainment', 'Wineries']],
#  ['mUk-0jToBuzk4KaDXp-uew', 3.0, ['Indian', 'Pakistani', 'Restaurants']],
#  ['fPRsXnya5q7oAOhcJdq3Gw', 4.0, ['Bakeries', 'Food']],
#  ['eOYgXjIdGhUgO27HXkKzmQ',
#   3.0,
#   ['Restaurants', 'Beer Garden', 'German', 'Swabian']],
#  ['kSldg-xQmqMGXrTyPdCLkg', 3.5, ['Beer', 'Wine & Spirits', 'Food']],
#  ['XFQbescZxNRAb2U-NwdLlg', 3.5, ['American (Traditional)', 'Restaurants']],
#  ['1CP8aJa8ILlfM5deroar0Q',
#   3.0,
#   ['Chicken Wings', 'American (New)', 'Restaurants']],
#  ['-xEGQKqXZzvkdyVQilQtrg', 1.5, ['Restaurants', 'Chinese']],
#  ['c3Ax5jq5kyekKWUgiaVJSw', 2.5, ['Pizza', 'Restaurants']],
#  ['jNbFKHT7j4XIxCsuKRC8WQ',
#   2.5,
#   ['Bars', 'Restaurants', 'Barbeque', 'Beer Bar', 'Nightlife']],
#  ['gduTP-ujJ89tWOSdb3WMPA', 3.5, ['Donuts', 'Food']],
#  ['x7lk5rE5u2KMV9pUm04gSA', 3.5, ['Bakeries', 'Food']],
#  ['N-FKBizx_wu3L8mvDPfYGw',
#   2.5,
#   ['Ice Cream & Frozen Yogurt', 'Desserts', 'Food']],
#  ['sQ6DZZLLJRfwUr0eDWKDDg', 4.0, ['Chinese', 'Restaurants', 'Asian Fusion']],
#  ['KBDRpZkCVJ5N_GSMIk4kPg', 4.0, ['Burgers', 'Fast Food', 'Restaurants']],
#  ['MqhxKfI7oMjUTMqH2gnhyg', 1.5, ['Fast Food', 'Restaurants', 'Burgers']],
#  ['EPkV2_H0TRcARa-2IFZ-2A', 2.0, ['Pizza', 'Restaurants']],
#  ['gQ93Na9yBJghX8HzH7smwQ', 3.0, ['Restaurants', 'Buffets']],
#  ['f8dJLMQ7UxV1mri5tbaJGA',
#   3.5,
#   ['Desserts', 'Coffee & Tea', 'Bakeries', 'Food']],
#  ['TYGVaav4hWZioQlk9Ig78A', 4.5, ['Restaurants', 'Barbeque']],
#  ['EUgHFeAvock2Ut3iWPlG8Q',
#   3.0,
#   ['Tex-Mex', 'Mexican', 'Fast Food', 'Restaurants']],
#  ['kSp9lWgQJrE9nsX7OS-x8w',
#   3.0,
#   ['Restaurants', 'Breakfast & Brunch', 'Diners']],
#  ['o9eVtV66qMtY0VmWyY2N9Q', 4.0, ['Bakeries', 'Food']],
#  ['Wbi-x-1Nbn6LFCMOSN6F5Q', 2.5, ['Restaurants', 'Mexican']],
#  ['U2a9GUewP6LyOilaQhue9g', 4.5, ['Barbeque', 'Restaurants']],
#  ['vEsAPc0fEDP1YPeSQanxfQ',
#   2.5,
#   ['Diners',
#    'Breakfast & Brunch',
#    'Restaurants',
#    'Burgers',
#    'Fast Food',
#    'American (New)']],
#  ['PM6nMLKgCPsW-1ukrbnDvg', 3.0, ['Grocery', 'Food']],
#  ['jCvnGFx3nWX51OkDW8mSsg', 2.5, ['Convenience Stores', 'Food']],
#  ['Fv621YzHSas5eYM8ppllhQ', 3.0, ['Vietnamese', 'Restaurants']],
#  ['vIstiRtK87OXR9aT54_8qQ', 3.0, ['Pizza', 'Restaurants']],
#  ['d8zFMcZ64Hwpj6IP6FscLg', 3.5, ['Caribbean', 'Restaurants']],
#  ['XjbGHMD0vDGcZkQoHQvF3A', 4.0, ['Food', 'Grocery']],
#  ['pPNcs_59jNiQSs0Yq13bGw', 3.0, ['Restaurants', 'American (Traditional)']],
#  ['nL_IofJ0sQVigmj3HInPPg', 3.5, ['Food', 'Grocery']],
#  ['5sTFevXhGx01eLT4wF7Urg',
#   3.5,
#   ['Restaurants',
#    'Nightlife',
#    'Bars',
#    'Lounges',
#    'American (New)',
#    'Italian',
#    'Mediterranean']],
#  ['W-3Sy3fy85mQdd0ZNFKIiw',
#   2.5,
#   ['Sports Bars',
#    'Nightlife',
#    'Burgers',
#    'Bars',
#    'American (Traditional)',
#    'Restaurants',
#    'Food']],
#  ['_2RhdxPmKnf8nVwAsI7Pzw', 4.0, ['Grocery', 'Food']],
#  ['bGSVy6nFFzpRMERVta3JiQ',
#   4.0,
#   ['Vegetarian', 'Restaurants', 'Asian Fusion', 'Gluten-Free']],
#  ['RnWZegos0nAjpPV00PPxBw',
#   3.0,
#   ['Pizza', 'Restaurants', 'Italian', 'Chicken Wings']],
#  ['iofGoeP8tLB7Ny4GNfjxvg', 4.0, ['Restaurants', 'Breakfast & Brunch']],
#  ['IxU1xb7j8SM9WPghWWlE_Q', 5.0, ['Hot Dogs', 'Burgers', 'Restaurants']],
#  ['TqAXKLF1P5XAIG9Uq2eUmQ',
#   4.5,
#   ['Restaurants', 'Latin American', 'Mexican', 'Fast Food', 'Chicken Shop']],
#  ['6I6uDGwCDggrWXi2T4lfaA', 3.5, ['Restaurants', 'Burgers']],
#  ['fbLYRHIZAt3q839whhaBUg', 3.5, ['Pizza', 'Italian', 'Restaurants']],
#  ['nJ71XaqT27UzIIzSQDHqOw', 3.5, ['Sushi Bars', 'Restaurants']],
#  ['EjaTArl3ofSeqpDdpGmdCg',
#   3.5,
#   ['Restaurants', 'Japanese', 'Thai', 'Asian Fusion']],
#  ['wkhxaIt6S9bQ0twAD9Svpw', 3.5, ['Restaurants', 'Pizza']],
#  ['wM8QNs7uSyDqMJKjBYFPCQ', 3.5, ['Buffets', 'Restaurants']],
#  ['jW4-bGuymLGlB9OBsTq3TA', 3.0, ['Italian', 'Pizza', 'Restaurants']],
#  ['uHGXcZ7Tydcg3HZ74S7Efg',
#   4.0,
#   ['Restaurants',
#    'Event Planning & Services',
#    'Venues & Event Spaces',
#    'Canadian (New)']],
#  ['Lazn_BTkm14Fw82EE_oUgQ',
#   1.5,
#   ['Music Venues',
#    'Nightlife',
#    'Sports Bars',
#    'Restaurants',
#    'American (New)',
#    'Bars',
#    'Arts & Entertainment']],
#  ['YHXczxm4W3BkGT-z7vZBBw',
#   3.5,
#   ['Chinese',
#    'Food',
#    'Coffee & Tea',
#    'Restaurants',
#    'Taiwanese',
#    'Tea Rooms']],
#  ['bwZqlLj8oYaML3ndlybeDg',
#   5.0,
#   ['Coffee & Tea',
#    'Customized Merchandise',
#    'Shopping',
#    'Coffee Roasteries',
#    'Bakeries',
#    'Food',
#    'Bagels']],
#  ['GhGYQ5WI4LdH53591fUMMA', 2.5, ['Restaurants', 'Chinese', 'Asian Fusion']],
#  ['Pt24B_tPolf9AhWoWD--qw', 2.5, ['Restaurants', 'Italian']],
#  ['TG-5UF3tHSP9xSq5L6b1Zg', 3.5, ['Restaurants', 'Sushi Bars', 'Japanese']],
#  ['rihKlAiPgJa5XcpZ1h9-bw',
#   1.5,
#   ['Fast Food', 'Chicken Wings', 'Restaurants']],
#  ['USQ5DOYyP6Puy3BU-QFu_Q',
#   4.0,
#   ['Shopping',
#    'Food',
#    'Grocery',
#    'Books',
#    'Mags',
#    'Music & Video',
#    'Newspapers & Magazines']],
#  ['9FzppK60NA4ou7CuPHPR3Q', 5.0, ['Coffee & Tea', 'Food', 'Food Trucks']],
#  ['fPmq8cfJv5MLp4RESiOnGQ',
#   3.5,
#   ['Tanning',
#    'Vitamins & Supplements',
#    'Beauty & Spas',
#    'Health Markets',
#    'Juice Bars & Smoothies',
#    'Food',
#    'Specialty Food',
#    'Shopping']],
#  ['TRgT7-WCdqKZWzMshEzk9g',
#   3.0,
#   ['Event Planning & Services',
#    'Bakeries',
#    'Caterers',
#    'Party & Event Planning',
#    'Public Services & Government',
#    'Restaurants',
#    'Food',
#    'Venues & Event Spaces',
#    'Italian',
#    'Community Centers']],
#  ['v12CYnuoOSA_DHzMBfbolw', 4.5, ['Soul Food', 'Restaurants']],
#  ['qUdGBSFkiPhEL6I718y-Gg', 3.5, ['Restaurants', 'Gastropubs']],
#  ['q_IcpNBbM9zZswlIS-hEGg', 4.0, ['Ice Cream & Frozen Yogurt', 'Food']],
#  ['0kyhbUW6NkpYjJzFBZ64vQ',
#   4.0,
#   ['Beer',
#    'Wine & Spirits',
#    'Food',
#    'Specialty Food',
#    'Restaurants',
#    'Sandwiches']],
#  ['iBH1TeUrJn1VuL59J1StUg', 3.0, ['Restaurants', 'Chinese']],
#  ['dXoeLzpG72P7F2Lwa01riQ', 2.5, ['Fast Food', 'Restaurants', 'Mexican']],
#  ['2rcrwnlPd_w5oieGVyDgpw', 4.0, ['Restaurants', 'Japanese']],
#  ['R93PaCrS4qai9u1uiiHPMw',
#   4.0,
#   ['Serbo Croatian',
#    'Restaurants',
#    'Mediterranean',
#    'International',
#    'Beer Garden',
#    'German']],
#  ['NMw6zTXoZDEzNchVIfL1pQ', 3.5, ['Restaurants', 'Mexican']],
#  ['1Ds8V2c7LlwSAA3O-9f4cA', 2.0, ['Burgers', 'Restaurants', 'Fast Food']],
#  ['kqO-dgJ_Ww17qVJXsPTfnw', 2.0, ['Bakeries', 'Food', 'Restaurants']],
#  ['XTUFys7dzAA3sO4HXWJavw',
#   2.0,
#   ['Coffee & Tea', 'Grocery', 'Bakeries', 'Food']],
#  ['iQ6ydwCOKHlz8BPpJpj2Zg',
#   3.0,
#   ['Event Planning & Services',
#    'Laundromat',
#    'Laundry Services',
#    'Cafes',
#    'Restaurants',
#    'Venues & Event Spaces',
#    'Local Services',
#    'Dry Cleaning & Laundry']],
#  ['Z7nGSKvjmHNRkXtoMxA3Jw',
#   3.0,
#   ['Restaurants',
#    'Barbeque',
#    'American (Traditional)',
#    'Steakhouses',
#    'Nightlife',
#    'Bars']],
#  ['cGHdjkXa2n9B2apkicdCXQ', 4.0, ['Food', 'Coffee & Tea']],
#  ['5TFXzPJh8JZK218_1aaTzg',
#   5.0,
#   ['Doctors',
#    'Beauty & Spas',
#    'Naturopathic/Holistic',
#    'Specialty Food',
#    'Health & Medical',
#    'Reflexology',
#    'Health Markets',
#    'Reiki',
#    'Food']],
#  ['L4PI4kh8plShtrcWt6aBTQ', 2.0, ['Chicken Wings', 'Restaurants', 'Pizza']],
#  ['eA8RJa5U2Ep8Ks3ECE6xfA',
#   3.0,
#   ['Restaurants', 'Bakeries', 'Grocery', 'Delis', 'Food']],
#  ['cdX8lf5BsJjpC82dzgtBZA',
#   4.0,
#   ['Nightlife', 'American (New)', 'Restaurants', 'Bars']],
#  ['Ty6v7AjBylVyAGHPQYRYwA', 2.5, ['Food', 'Ice Cream & Frozen Yogurt']],
#  ['9DHE9JieR80pYkpyr19iZQ', 4.0, ['Italian', 'Pizza', 'Restaurants']],
#  ['tM_MMrMFwf5rJv9rbu4NQQ', 3.0, ['Seafood', 'Fish & Chips', 'Restaurants']],
#  ['PY5Y_9-7S-MorAo_Cgqu-Q',
#   2.5,
#   ['Canadian (New)', 'Nightlife', 'Lounges', 'Bars', 'Restaurants']],
#  ['Q2bnRzJ8AC-3lWyQY8DZqA', 2.5, ['Restaurants', 'Barbeque']],
#  ['YFEwCxc-9WRRVGgRv_-p7Q',
#   3.0,
#   ['Ramen', 'Asian Fusion', 'Korean', 'Japanese', 'Restaurants']],
#  ['LPca2wc7lQ7xm7az4KMBrA', 3.5, ['Nightlife', 'Bars', 'Restaurants']],
#  ['vjLgZg0DH_9xwcujFNb0pA', 1.5, ['Restaurants', 'Buffets']],
#  ['hupeXWY97YCwZQYC79F6hQ',
#   3.0,
#   ['Restaurants',
#    'Bagels',
#    'Food',
#    'Sandwiches',
#    'Breakfast & Brunch',
#    'Salad',
#    'Soup']],
#  ['rtcWSNA3HVehrnUDVphYoA', 3.0, ['Fast Food', 'Sandwiches', 'Restaurants']],
#  ['mi9cuuxuzwNQDvyFdLwysg',
#   2.5,
#   ['Specialty Food', 'Food', 'Grocery', 'Seafood Markets']],
#  ['0kzPQQL8wVcHlBQzMdRdWQ',
#   3.5,
#   ['Sandwiches',
#    'Burgers',
#    'Restaurants',
#    'Barbeque',
#    'American (Traditional)']],
#  ['A7Glhmj0YLp-kqzfWmu8_Q',
#   4.0,
#   ['Food', 'Desserts', 'Chocolatiers & Shops', 'Bakeries', 'Specialty Food']],
#  ['5TXQxcwEfqzBDbMq2zmBPQ',
#   4.0,
#   ['American (New)', 'Steakhouses', 'Italian', 'Restaurants']],
#  ['ZKSivkZcnH-nfqcIS8PUWA', 4.5, ['Restaurants', 'Buffets', 'Indian']],
#  ['XtJj67rKT16a4tQw7bxtyw', 2.5, ['Restaurants', 'Thai']],
#  ['O3OH5IEFMPtz7mPKakPZ3Q',
#   4.5,
#   ['Tapas Bars',
#    'Restaurants',
#    'French',
#    'Asian Fusion',
#    'Japanese',
#    'Seafood']],
#  ['koqazXBW7wAZVry72u5vEw', 3.0, ['Pizza', 'Restaurants']],
#  ['8bskEwLJsPe2X3Avixab-Q',
#   4.0,
#   ['Tapas/Small Plates',
#    'Nightlife',
#    'Food',
#    'Restaurants',
#    'Beer Bar',
#    'Bars',
#    'Breweries']],
#  ['0B3W6KxkD3o4W4l6cq735w', 3.0, ['Poutineries', 'Burgers', 'Restaurants']],
#  ['q7OKOkEK-pgAQNjDiVd4bA',
#   3.0,
#   ['American (Traditional)', 'Restaurants', 'Burgers']],
#  ['veU3mhOn8kF87VfE_JvKlg',
#   3.0,
#   ['Pizza', 'Fast Food', 'Cafeteria', 'Restaurants']],
#  ['YGU2RnqsJO7Izs1GLDhMLQ', 3.5, ['Restaurants', 'Sushi Bars']],
#  ['whAwdYVty-jSNRhrYT2zHA', 4.0, ['Cajun/Creole', 'Seafood', 'Restaurants']],
#  ['cnXyideAGnrIjKjLjOZcHA',
#   4.0,
#   ['Shaved Ice', 'Ice Cream & Frozen Yogurt', 'Food', 'Desserts']],
#  ['puPY7gVy7RCz8bK1zkzdoQ', 4.0, ['Chinese', 'Restaurants']],
#  ['adTbcC7JgvzYg7AD_Ga-rg',
#   4.0,
#   ['Latin American', 'Restaurants', 'Salvadoran']],
#  ['u5Xa3N90_jhbBGKU2e4Y3w',
#   5.0,
#   ['Seafood', 'Italian', 'Restaurants', 'Greek']],
#  ['y-O3h7CV6X6P5ey1ZFcQwA',
#   5.0,
#   ['Health & Medical',
#    'Food Delivery Services',
#    'American (New)',
#    'Restaurants',
#    'Specialty Food',
#    'Health Markets',
#    'Home Services',
#    'Desserts',
#    'Weight Loss Centers',
#    'Food']],
#  ['gpivFNirREOyEAwxVebR5g', 2.5, ['Fast Food', 'Burgers', 'Restaurants']],
#  ['FmBKx7mv-jdh6KJ7Vq2v5w', 3.5, ['Filipino', 'Thai', 'Restaurants']],
#  ['QMabpBYQ2qAh16GPbCvMrA',
#   3.0,
#   ['Restaurants', 'Burgers', 'Fast Food', 'Food']],
#  ['HnbWx7Q8P4-MXbxMpb-qVw', 4.0, ['Food', 'Coffee & Tea']],
#  ['VobZRj98tDH7AaojYJD8Jg',
#   3.0,
#   ['Bars',
#    'Restaurants',
#    'American (New)',
#    'American (Traditional)',
#    'Nightlife',
#    'Burgers',
#    'Sports Bars']],
#  ['1N6_FgS6nq5eT_3x4MXm4A',
#   5.0,
#   ['Food', 'Ice Cream & Frozen Yogurt', 'Convenience Stores']],
#  ['ky4AyA_y6gx20tf95mZxSA',
#   3.5,
#   ['Bed & Breakfast',
#    'Event Planning & Services',
#    'Hotels & Travel',
#    'Hotels',
#    'Restaurants',
#    'Diners']],
#  ['xK4ZY4t88g9LD_SHMaQ3VA', 3.5, ['Food', 'Ice Cream & Frozen Yogurt']],
#  ['kmMx1em0IDc6zb7hqJctvw', 3.0, ['Bakeries', 'Food']],
#  ['R3oY1XsFcagS0UEEJQjANA', 4.0, ['Coffee & Tea', 'Food']],
#  ['YcLwfuSR3LOY4vnUKpDC4Q', 4.0, ['Restaurants', 'Indian', 'Pakistani']],
#  ['8n4dyb1m1BwHltydpH-Qhg',
#   3.0,
#   ['Cajun/Creole', 'Steakhouses', 'Restaurants', 'Gluten-Free', 'Seafood']],
#  ['qy2uJwO1D8pT96SwGY3ubg', 3.5, ['Restaurants', 'Fast Food']],
#  ['6tR-uUoy8CScXuSRMw2igQ',
#   3.5,
#   ['Restaurants', 'Bavarian', 'Palatine', 'Beer Garden', 'German']],
#  ['rBBYRHZk2Bs5IW-GLZm7Tw', 4.0, ['Bakeries', 'Food']],
#  ['Z573XZf-CR1X_Kw7-eKJhg',
#   3.5,
#   ['Juice Bars & Smoothies',
#    'Restaurants',
#    'Food',
#    'Fast Food',
#    'Cafes',
#    'Sandwiches',
#    'Coffee & Tea']],
#  ['opnw3jgcHUsfHCv6YosKgQ', 3.5, ['Restaurants', 'Coffee & Tea', 'Food']],
#  ['2xcnolaD9e6voXJnrbu_Hg', 4.0, ['Specialty Food', 'Food', 'Candy Stores']],
#  ['ujcbqs6jZfaESgSLvbjWuQ', 3.5, ['Restaurants', 'Japanese', 'Sushi Bars']],
#  ['nzbQXU2x7O8oucKGthUT3g', 4.0, ['Restaurants', 'Pizza']],
#  ['Dwj3s0jTQM7-r8joZSe2sw', 3.0, ['Restaurants', 'Burgers', 'Fast Food']],
#  ['BVxen382pORVZNQEDdQlKQ', 3.0, ['Restaurants', 'Middle Eastern']],
#  ['1_y5e1u-o93EKOigXgR3LQ',
#   4.0,
#   ['Latin American',
#    'Event Planning & Services',
#    'Caterers',
#    'Mexican',
#    'Restaurants']],
#  ['XoSJDOBj8Pf8GOhhOuw9mw',
#   3.5,
#   ['Middle Eastern',
#    'Specialty Food',
#    'Restaurants',
#    'Ethnic Food',
#    'Imported Food',
#    'Food']],
#  ['2LVuwl-eH-8PYikyFmqcTQ', 2.5, ['Restaurants', 'Pizza']],
#  ['VUb97h3RTg6InKdfgB49Bw',
#   4.0,
#   ['Restaurants',
#    'Bars',
#    'Arts & Entertainment',
#    'Nightlife',
#    'Hot Dogs',
#    'American (Traditional)',
#    'Music Venues',
#    'Dive Bars']],
#  ['57A0dLJ8dvnFUgUTu0vBnw',
#   4.0,
#   ['Food Stands', 'Desserts', 'Restaurants', 'Food']],
#  ['kukAC7aIGvS-7JiS-_pSiw', 4.5, ['Desserts', 'Food', 'Bakeries']],
#  ['F6Ujpp1Kh7L_3uUfoUsTlw',
#   4.0,
#   ['Ice Cream & Frozen Yogurt', 'Pizza', 'Restaurants', 'Food', 'Italian']],
#  ['hMe7hiCo90jnMXyzmPnO6Q', 2.0, ['Restaurants', 'Mexican']],
#  ['V80NaT5ZnfuA31yW3Y5Pdg',
#   5.0,
#   ['Street Vendors', 'Mexican', 'Restaurants', 'Food', 'Food Trucks']],
#  ['ExoqgA3aAz6bYidI0DSQvw', 3.5, ['Sandwiches', 'Food', 'Restaurants']],
#  ['t6SfYTEvg0o_cfJddsqEcg', 2.5, ['Food', 'Coffee & Tea']],
#  ['k1Nm4agS92jbY8ZKlG1UYQ', 2.5, ['Food', 'Grocery']],
#  ['37kk0IW6jL7ZlxZF6k2QBg', 4.0, ['Spanish', 'French', 'Restaurants']],
#  ['U9hNGJFMh5vZsLMZQNellw',
#   3.0,
#   ['Restaurants', 'Buffets', 'Breakfast & Brunch', 'Italian']],
#  ['qsEbriXbvQVaORyJSkCEzQ', 3.0, ['Coffee & Tea', 'Food']],
#  ['le4fLtpLE3PdGnqRFr537w', 3.0, ['Pizza', 'Restaurants']],
#  ['PgtOActam5PdtWn45dl-mQ', 3.0, ['Grocery', 'Food']],
#  ['VCkKTkLWh9dY5vSdNPZDqw', 4.5, ['Specialty Food', 'Food']],
#  ['8cusyHsqMhNAsrNSMpzB1A',
#   4.0,
#   ['Food', 'Restaurants', 'American (Traditional)', 'Smokehouse', 'Barbeque']],
#  ['CtYWpX_cy1YdZgoKtS0Tqg', 2.0, ['Pizza', 'Restaurants']],
#  ['Y2ySw4qMHgjd1T_2Zt9Eeg',
#   3.5,
#   ['Ice Cream & Frozen Yogurt', 'Food', 'Do-It-Yourself Food', 'Desserts']],
#  ['sUzvletCYiIaZD_hbnNLEA',
#   3.0,
#   ['Fast Food', 'Tex-Mex', 'Restaurants', 'Mexican']],
#  ['XvhSYgpJx6mc5MycXac-Iw',
#   3.0,
#   ['Restaurants', 'Sandwiches', 'Food Delivery Services', 'Delis', 'Food']],
#  ['KlLivbkatzoYKelYI-E-AA', 4.0, ['Restaurants', 'Tapas Bars', 'Spanish']],
#  ['Xv1nmXd4IM5kG2g-VLG7nQ',
#   4.5,
#   ['Chocolatiers & Shops', 'Food', 'Candy Stores', 'Specialty Food']],
#  ['eS76100l3h7Ollb5s3_M4A',
#   4.0,
#   ['Bagels',
#    'Breakfast & Brunch',
#    'Restaurants',
#    'Coffee & Tea',
#    'Juice Bars & Smoothies',
#    'Bakeries',
#    'Food']],
#  ['K8ZeT5Y5L0SDh18wO0ZOAQ',
#   1.5,
#   ['Fruits & Veggies',
#    'Food Delivery Services',
#    'Food',
#    'Greek',
#    'Comfort Food',
#    'Restaurants',
#    'Specialty Food']],
#  ['atNuup_649IY1B1L1vTkow', 2.0, ['Restaurants', 'Sandwiches']],
#  ['Cr9yQp1qrYOJTx1J-aCWeQ', 3.5, ['Coffee & Tea', 'Food', 'Bakeries']],
#  ['FiRAbcgD7ja2suCv8NANRg', 4.0, ['Food', 'Grocery']],
#  ['rVVEKv3F6ZzvA-FcorhzvQ', 3.5, ['Fast Food', 'Burgers', 'Restaurants']],
#  ['DtuC7O4Aw63gPnG0eCxGKQ', 2.5, ['Restaurants', 'Cafes']],
#  ['p_wgylnWMXSLlPGCRYSarQ', 3.0, ['Restaurants', 'American (Traditional)']],
#  ['G0EJjh-dqJBmSEhQRog-hQ',
#   4.5,
#   ['Restaurants', 'Fast Food', 'Burgers', 'Sandwiches']],
#  ['o-4US-ls34JMq3nPSkw1WA', 3.5, ['Restaurants', 'Fast Food', 'Comfort Food']],
#  ['8s-kkY82WuATczo1YPiRqA', 3.5, ['Grocery', 'Food']],
#  ['i-zvRNJ-KSG-sfdAzwImQQ', 3.5, ['Indian', 'Vegetarian', 'Restaurants']],
#  ['KBN8wcnBr9KRB4TPa0unsQ', 3.0, ['Restaurants', 'German']],
#  ['7fq6fN58ogXAzXzxywFX1Q', 4.0, ['Restaurants', 'Mexican']],
#  ['qQQp8UzMhQK0-hZ3Bktbaw', 4.5, ['Food', 'Bakeries']],
#  ['0cxO1Lx2Pi7u6ftWX3Wksg', 3.0, ['Soul Food', 'Restaurants']],
#  ['CsT6cn881bdQySTYbdVaDA', 2.5, ['Bakeries', 'Food', 'Desserts']],
#  ['ua6EalI7V0a0ZogIIrKAbw',
#   4.0,
#   ['Bakeries', 'Restaurants', 'Tea Rooms', 'Food', 'Cafes']],
#  ['dlLG3yMa9UtU5K0VjOLmFA',
#   4.0,
#   ['Food', 'Chocolatiers & Shops', 'Specialty Food', 'Desserts']],
#  ['sTfs8QwqzcgTe9GFz99FGQ',
#   4.5,
#   ['Shopping',
#    'Food',
#    'Tobacco Shops',
#    'Beer',
#    'Wine & Spirits',
#    'Convenience Stores']],
#  ['gKXsFVhWyK7MLQhSKG5_mA', 2.5, ['Pizza', 'Sandwiches', 'Restaurants']],
#  ['r5PLDU-4mSbde5XekTXSCA',
#   4.5,
#   ['Delis', 'Sandwiches', 'Restaurants', 'Italian']],
#  ['x6bet3EbqPvtw4DSVNWIDw',
#   4.0,
#   ['Restaurants',
#    'Event Planning & Services',
#    'Nightlife',
#    'Hotels & Travel',
#    'German',
#    'Beer Gardens',
#    'Hotels']],
#  ['T96EG2iK3ZSv9ACiSFw4cw', 3.5, ['Sushi Bars', 'Restaurants']],
#  ['GBT2NAN_-6PmL_xzabeh7A', 2.5, ['Food', 'Beer', 'Wine & Spirits']],
#  ['BCBLDV5sxvOebPRswPFFgA',
#   1.0,
#   ['Hot Dogs', 'Fast Food', 'Restaurants', 'Burgers']],
#  ['JM9LVlM_o3k_CbCErIQYAg', 3.0, ['Chinese', 'Fast Food', 'Restaurants']],
#  ['NM3iiGNrwoyNKWXiRT-nKA',
#   2.5,
#   ['Noodles',
#    'Sushi Bars',
#    'Restaurants',
#    'Tapas/Small Plates',
#    'Asian Fusion']],
#  ['9Cq_NVvWZOEAzmE7tqJgmg',
#   4.5,
#   ['Food Trucks',
#    'Restaurants',
#    'American (New)',
#    'Food',
#    'Food Stands',
#    'Hot Dogs']],
#  ['Q4orLuzDAB9TnucYXksgLQ', 3.5, ['Restaurants', 'Burgers']],
#  ['A8y3yc_-_cDrHiApqJlx-w',
#   2.5,
#   ['Drugstores',
#    'Cosmetics & Beauty Supply',
#    'Food',
#    'Beauty & Spas',
#    'Convenience Stores',
#    'Shopping']],
#  ['gSR9bmBa0HacSuMX5BIAxg',
#   3.0,
#   ['Bakeries', 'American (New)', 'Food', 'Restaurants']],
#  ['uFGmCUqJc0vy57IF_26u1g', 4.0, ['Beer', 'Wine & Spirits', 'Food']],
#  ['uxmL96QngoslrtMXaQ80nA', 4.0, ['Thai', 'Restaurants']],
#  ['h23R_mGy3ZdKlOYj57bheQ',
#   3.0,
#   ['Hotels & Travel',
#    'Event Planning & Services',
#    'Convenience Stores',
#    'Hotels',
#    'Caterers',
#    'Food']],
#  ['hQ8JN52MjxbMUPfuhyL7jQ',
#   3.5,
#   ['American (Traditional)',
#    'Fast Food',
#    'Chicken Wings',
#    'Chicken Shop',
#    'Restaurants']],
#  ['6Qpy6U_IPP-r_vZKTmugMw',
#   4.0,
#   ['Specialty Food',
#    'Grocery',
#    'Fruits & Veggies',
#    'Delicatessen',
#    'Food',
#    'Convenience Stores']],
#  ['0hBGwOLU2UfiYXkM8wc8Hw', 3.0, ['German', 'Beer Garden', 'Restaurants']],
#  ['x2nItJPCZxEobThRyDg6HQ', 3.0, ['Mexican', 'Fast Food', 'Restaurants']],
#  ['ohGaxI7vLlEqN1H0GYlFUA', 3.5, ['Restaurants', 'Burgers']],
#  ['PI2wL546eakla9qPI3vqhA', 2.5, ['American (New)', 'Restaurants']],
#  ['XjbPr3o-YTsticeavLjTEg',
#   2.0,
#   ['Sports Bars',
#    'Bars',
#    'Restaurants',
#    'Barbeque',
#    'Nightlife',
#    'Chicken Wings']],
#  ['n8GCGa5gX17Ibix5VsGMuw',
#   3.5,
#   ['Fast Food', 'Restaurants', 'Chicken Wings']],
#  ['PLa2EQ60fVpHoxJC5UmQ-A', 4.0, ['Restaurants', 'Barbeque', 'Portuguese']],
#  ['taQyhYtNzD4vujSvP3CDkQ',
#   4.5,
#   ['Food', 'Shaved Ice', 'Ice Cream & Frozen Yogurt', 'Desserts']],
#  ['Jk2XwkySutg0glHVcv1_Pw',
#   4.0,
#   ['Bars',
#    'Wine Bars',
#    'Restaurants',
#    'Food',
#    'Nightlife',
#    'Beer',
#    'Wine & Spirits',
#    'Specialty Food',
#    'Tapas/Small Plates']],
#  ['hJJm0DFmG57zwSeNkeIuRQ', 1.0, ['Mexican', 'Restaurants']],
#  ['rN3gHTjqx5sOnoUpJ-6jyg', 4.0, ['Restaurants', 'Steakhouses']],
#  ['Y22IfhXChXoRp3vKi6QwaQ', 4.0, ['Chinese', 'Restaurants']],
#  ['eCJDiRPoSuA0bsb7F1gNUA',
#   4.0,
#   ['Asian Fusion', 'Chinese', 'Restaurants', 'Fast Food', 'Szechuan']],
#  ['MhINNBBwzGn4-n_YI67wog',
#   3.0,
#   ['Restaurants', 'Tex-Mex', 'Bars', 'Pizza', 'Nightlife', 'Sports Bars']],
#  ['Zv77o3aDuNDY0t3fCU2ebQ', 3.5, ['Pizza', 'Restaurants', 'Italian']],
#  ['Q1LrCiy0D6uqliWKe-BxtQ',
#   2.5,
#   ['Restaurants',
#    'Food',
#    'Beer',
#    'Wine & Spirits',
#    'Wine Bars',
#    'Vegetarian',
#    'Local Flavor',
#    'Tapas/Small Plates',
#    'Nightlife',
#    'Bars']],
#  ['L4ivYHVCDpIE0SrPaCn0LA',
#   3.5,
#   ['Nightlife', 'Pubs', 'Restaurants', 'Gastropubs', 'Bars']],
#  ['gqGrMnDYEToXOYajBuEvKQ',
#   2.0,
#   ['Italian', 'Restaurants', 'Chicken Wings', 'Pizza']],
#  ['LwQB9H3jZ9wTk24Lr-AnZQ',
#   4.0,
#   ['American (Traditional)', 'American (New)', 'Restaurants', 'Pizza']],
#  ['kLVK8y8YQeRkJeld5eZbwg',
#   3.0,
#   ['Bars', 'Restaurants', 'American (Traditional)', 'Pubs', 'Nightlife']],
#  ['5IWOWl4Kn-1Ss9zLPrj1aA', 3.0, ['Sandwiches', 'Restaurants']],
#  ['nIroO3-n_GqxlUMvhNjxEQ', 4.0, ['Food', 'Coffee & Tea']],
#  ['dD6JQo5tCNtOtauaLaT0sg',
#   3.5,
#   ['Sports Bars',
#    'Restaurants',
#    'Food',
#    'Pizza',
#    'Nightlife',
#    'Bars',
#    'Breweries']],
#  ['Bwj6xuHNWmI2w88DzBc1vQ', 3.0, ['Food', 'Grocery']],
#  ['Us7Oe7hwI3J9rJ2TZs8gSw',
#   2.5,
#   ['Restaurants',
#    'Chicken Shop',
#    'Fast Food',
#    'Breakfast & Brunch',
#    'Chicken Wings']],
#  ['WKTZk-2cH780mJGnJswwHQ',
#   3.0,
#   ['Specialty Food',
#    'Ethnic Food',
#    'Imported Food',
#    'Event Planning & Services',
#    'Caterers',
#    'Food']],
#  ['cXJCsKcp5BAs1v4Q2Ocr8A',
#   4.0,
#   ['Flowers & Gifts',
#    'Shopping',
#    'Beer',
#    'Wine & Spirits',
#    'Food',
#    'Grocery',
#    'Tobacco Shops']],
#  ['8hZuRG3FiEpfLZeQWdJeZw',
#   4.0,
#   ['Specialty Food', 'Health Markets', 'Food', 'Organic Stores', 'Grocery']],
#  ['rcvX62QPMKs_ddYitm4Yag', 3.0, ['Coffee & Tea', 'Food']],
#  ['SNn_I8VMds60C4bSXCyUtw', 4.0, ['Restaurants', 'Indonesian']],
#  ['rxA9c0_XObabVL1WCTA4FA',
#   3.5,
#   ['Breakfast & Brunch',
#    'Nightlife',
#    'Dive Bars',
#    'Tex-Mex',
#    'Restaurants',
#    'Bars']],
#  ['8sIhwpTvbMq77kCSmWl7Cg', 3.5, ['Food', 'Grocery']],
#  ['REJPrXEZly4PDQNmiMGI8Q',
#   3.0,
#   ['Mexican', 'Food', 'Restaurants', 'Specialty Food', 'Tacos']],
#  ['KYvjCd1vcKpvngwWjby0kg',
#   2.5,
#   ['Beauty & Spas',
#    'Doctors',
#    'Cosmetic Surgeons',
#    'Health & Medical',
#    'Day Spas',
#    'Medical Spas',
#    'Food']],
#  ['ll9PWPSzuHudE8J1BT1G2A', 4.0, ['Coffee & Tea', 'Food']],
#  ['CYFfha5CmApflbpN1AhWHQ',
#   3.5,
#   ['Farmers Market',
#    'Food Trucks',
#    'Restaurants',
#    'Street Vendors',
#    'Food',
#    'Sandwiches']],
#  ['1NyHpXJqSLHnvDCOW0nJDg', 3.0, ['Pizza', 'Restaurants']],
#  ['YQ--LJ7pvjiDSqNv0TuKTQ', 4.0, ['Restaurants', 'Pizza']],
#  ['m38PfxkTGgINuArSTX16iQ',
#   4.0,
#   ['Halal', 'Indian', 'Restaurants', 'Pakistani']],
#  ['7T_2djdY6ldRugsuWb2S-A', 3.0, ['Restaurants', 'Breakfast & Brunch']],
#  ['4hG2j_ibsNblDgqei05U_g',
#   4.0,
#   ['Japanese', 'Lounges', 'Bars', 'Nightlife', 'Asian Fusion', 'Restaurants']],
#  ['afXMX5llxcMFzbaPaBBm6A', 3.5, ['Restaurants', 'Italian']],
#  ['8_kbZ8PfEEzREMiYqv6iyQ', 2.5, ['Food', 'Candy Stores', 'Specialty Food']],
#  ['H5oLlt9G6ifU11n86oP5Fg', 5.0, ['Bakeries', 'Food']],
#  ['769NudnrUxWFtJCGU66A_A',
#   3.0,
#   ['American (New)',
#    'Restaurants',
#    'Canadian (New)',
#    'American (Traditional)',
#    'Breakfast & Brunch',
#    'Diners']],
#  ['_XM07jbQGliVPwnAfyyGUA', 3.0, ['Kosher', 'Restaurants']],
#  ['mgc8BmE6Tdt4MVOy6siZoA', 2.5, ['Food Court', 'Restaurants', 'Food']],
#  ['j_QIPSIk-O7oluwHbfMtNg',
#   4.0,
#   ['Food', 'Beer', 'Wine & Spirits', 'Vietnamese', 'Thai', 'Restaurants']],
#  ['sPd9YmvS6eSWzTvqowcBXA',
#   3.0,
#   ['Juice Bars & Smoothies',
#    'Sandwiches',
#    'Food',
#    'Restaurants',
#    'Breakfast & Brunch']],
#  ['g-aAe8SqZlZTnN3oA8mNlw',
#   2.5,
#   ['Mexican', 'Breakfast & Brunch', 'Restaurants', 'Food', 'Desserts']],
#  ['w43yHlJzoCEqUVNRezo_7A',
#   4.5,
#   ['Professional Services',
#    'Wholesalers',
#    'Fruits & Veggies',
#    'Food',
#    'Specialty Food',
#    'Grocery',
#    'Restaurant Supplies']],
#  ['vrpW_ZIjHvsAX3ByyeHjCA',
#   3.5,
#   ['American (New)', 'Italian', 'Restaurants', 'Seafood']],
#  ['vPmk2RaVKYlvjvEqBr2abA',
#   2.5,
#   ['American (Traditional)',
#    'American (New)',
#    'Restaurants',
#    'Breakfast & Brunch',
#    'Diners']],
#  ['JXYeMN_VyIZyrveANnIVpA', 2.5, ['Sandwiches', 'Restaurants', 'Fast Food']],
#  ['-2bYV9zVtn2F5XpiAaHt5A', 3.0, ['Restaurants', 'Delis']],
#  ['2skQeu3C36VCiB653MIfrw',
#   4.0,
#   ['Nightlife',
#    'Bars',
#    'Food',
#    'Restaurants',
#    'Smokehouse',
#    'American (Traditional)',
#    'Barbeque']],
#  ['5PLQltRcNFEe18ApJQgoSg',
#   4.0,
#   ['Event Planning & Services',
#    'Restaurants',
#    'Hotels',
#    'Swabian',
#    'Austrian',
#    'Hotels & Travel']],
#  ['EVe1uRxc6qBdvd9lTWSH4g', 2.0, ['Fast Food', 'Burgers', 'Restaurants']],
#  ['epoEBSCz3Mh4X-vVvcioNA',
#   3.0,
#   ['Bars', 'Italian', 'Nightlife', 'Lounges', 'Restaurants']],
#  ['V1FSee0pZ-yReDQ28SAO3g',
#   4.5,
#   ['Breakfast & Brunch', 'Restaurants', 'Diners']],
#  ['DXn79Dzv8kpsMcNNKZHuRA',
#   4.0,
#   ['Specialty Food',
#    'Beer',
#    'Wine & Spirits',
#    'Imported Food',
#    'Food',
#    'Grocery',
#    'International Grocery',
#    'Ethnic Food']],
#  ['1N1pVa5SYqzopS0wvlAavw', 1.0, ['Burgers', 'Restaurants']],
#  ['3SQU0IgQ6mbV0buzH9XAZA', 4.5, ['Sandwiches', 'Restaurants']],
#  ['xSZQa9ez44TJ0tiVHSY1Mw', 3.5, ['Mexican', 'Restaurants']],
#  ['_3o05Wdjfc8jOvGZ_q177Q', 2.5, ['Restaurants', 'Mexican']],
#  ['AyXxQqNAeToBTL-M5TWWxA', 4.0, ['Restaurants', 'Bakeries', 'Delis', 'Food']],
#  ['WgCx3vMpALkUo4w-zrHjhg',
#   4.0,
#   ['Mediterranean', 'Restaurants', 'Greek', 'Middle Eastern']],
#  ['UPqUPTwy5BagQyCWYrJ44g', 3.0, ['Restaurants', 'Japanese']],
#  ['LHYFHwPo1hKp8plKsMPXmA',
#   4.5,
#   ['Hawaiian',
#    'Food',
#    'Juice Bars & Smoothies',
#    'Coffee & Tea',
#    'Restaurants']],
#  ['AqWBhU6SM7n6iY_q6o46Tw',
#   5.0,
#   ['Investing',
#    'Restaurants',
#    'Barbeque',
#    'Lawyers',
#    'Southern',
#    'Financial Services',
#    'Bankruptcy Law',
#    'Breakfast & Brunch',
#    'Professional Services']],
#  ['IV9xmEWafjYmAGnM_HUZGQ',
#   4.5,
#   ['Fruits & Veggies', 'Food', 'Grocery', 'Specialty Food']],
#  ['s_YDnDZRLk6VJWRQyd_F2A',
#   4.5,
#   ['Restaurants', 'Fish & Chips', 'Breakfast & Brunch']],
#  ['bGWI4ukY0PlnXzKICDZdGA',
#   3.5,
#   ['Food', 'Restaurants', 'Burgers', 'Ice Cream & Frozen Yogurt']],
#  ['6zeCTHZkBho2lPn3LuyzDA', 4.5, ['Food', 'Grocery']],
#  ['v4qyBRpTBvOO55M4IAqNNg',
#   3.5,
#   ['Asian Fusion', 'Japanese', 'Sushi Bars', 'Restaurants']],
#  ['KMAC_44vOPCVH-E_doOisQ',
#   4.0,
#   ['Nightlife',
#    'Restaurants',
#    'Dominican',
#    'Bars',
#    'Latin American',
#    'Caribbean']],
#  ['7UgP42G-5gtqlzfBtDuIAA',
#   3.0,
#   ['Thai', 'Halal', 'Restaurants', 'Indian', 'Chinese']],
#  ['UkqdcwYv6_c-yW1JPCKlUA', 3.5, ['Restaurants', 'Italian', 'Delis']],
#  ['NoDhna4BsDhcl7xRPmZJzQ',
#   4.0,
#   ['Restaurants', 'Sushi Bars', 'Soup', 'Salad']],
#  ['vn_UN1JnA57hpayj6ETpRQ',
#   2.5,
#   ['American (Traditional)', 'Breakfast & Brunch', 'Restaurants']],
#  ['6ySrrRnMB_vb1oTroNFD4A',
#   4.5,
#   ['Coffee & Tea', 'Food', 'Coffee Roasteries']],
#  ['K-uQkfSUTwu5LIwPB4b_vg',
#   4.0,
#   ['Restaurants', 'Bars', 'Mexican', 'Latin American', 'Nightlife']],
#  ['fN7ds9Dk4IfMsh4RT9x82w',
#   4.5,
#   ['Bars',
#    'Restaurants',
#    'Asian Fusion',
#    'Nightlife',
#    'Sushi Bars',
#    'Japanese']],
#  ['OeW7ulF-qyrj6uLLUsuSLg',
#   4.0,
#   ['Food', 'Custom Cakes', 'Bakeries', 'Cupcakes']],
#  ['kByQQ4yd7ZbA0MAQKmRVvg',
#   2.5,
#   ['American (Traditional)', 'Nightlife', 'Restaurants', 'Bars']],
#  ['LM-_1Ye4Ufn9zxEuZkIvEw',
#   5.0,
#   ['Hotels',
#    'Restaurants',
#    'Event Planning & Services',
#    'Greek',
#    'Hotels & Travel']],
#  ['NOz8W_cUV3Dw5yLgFkKLGw',
#   3.0,
#   ['Pubs', 'Restaurants', 'Burgers', 'Nightlife', 'Bars']],
#  ['ZJLobjytBCP0RRxhbBkS8Q',
#   3.5,
#   ['Chocolatiers & Shops', 'Food', 'Specialty Food']],
#  ['AgUYUBTHnQZL6No_1ljP6w', 3.5, ['Grocery', 'Food']],
#  ['OLg1IeS-QxZgNprQ4Hg9gg',
#   3.5,
#   ['Restaurants', 'Belgian', 'American (Traditional)']],
#  ['Nc0xqiAmS2OTxPrlvQrJ4A',
#   3.5,
#   ['Restaurants', 'American (Traditional)', 'Soul Food', 'Southern']],
#  ['1mkDrJRu3VABKy95gxD-Hg',
#   4.5,
#   ['American (Traditional)', 'Soul Food', 'Restaurants', 'Seafood']],
#  ['X6iU1PGjoztDwFdhV4RumA', 2.0, ['Restaurants', 'Fast Food', 'Burgers']],
#  ['Va-VdrGmGiqJ4KfLnCk6Yg',
#   2.5,
#   ['American (Traditional)', 'Restaurants', 'Hot Dogs']],
#  ['HWoTYO4kMrV113oJZs1JVw',
#   3.0,
#   ['Grocery', 'Specialty Food', 'Organic Stores', 'Health Markets', 'Food']],
#  ['-0DET7VdEQOJVJ_v6klEug', 3.0, ['Asian Fusion', 'Restaurants']],
#  ['0YWsZ1Ie9e04DFfzFij7yQ', 2.5, ['American (New)', 'Restaurants']],
#  ['6DCTAExBd7sp92BcAl80Qw', 4.5, ['Pizza', 'Bakeries', 'Food', 'Restaurants']],
#  ['l5LHGuxV-rGFswpzvYd8Lg', 3.5, ['Specialty Food', 'Meat Shops', 'Food']],
#  ['0AJF-USLN6K5T4caooDdjw', 3.0, ['Coffee & Tea', 'Food']],
#  ['l6ChWz5fwhkvuEmThuFl5w',
#   3.5,
#   ['Food', 'Vegan', 'Restaurants', 'Coffee & Tea']],
#  ['11bhfBbcFypczdz3N_w6iw', 3.5, ['Mexican', 'Fast Food', 'Restaurants']],
#  ['MV9fUwgI2AQa4uZArynRlA', 3.0, ['Mexican', 'Restaurants']],
#  ['85nvKTJSN8byoeGRxzGkug',
#   4.0,
#   ['Cafes', 'American (Traditional)', 'Breakfast & Brunch', 'Restaurants']],
#  ['LP6qd2sUvDcL2LoQjULk3g',
#   5.0,
#   ['Food Trucks',
#    'American (Traditional)',
#    'Restaurants',
#    'Food',
#    'Barbeque',
#    'Sandwiches',
#    'Comfort Food',
#    'Cuban']],
#  ['o7WABjZct-u2gpBR8LXckQ',
#   4.0,
#   ['Convenience Stores',
#    'Department Stores',
#    'Gas Stations',
#    'Shopping',
#    'Food',
#    'Wholesale Stores',
#    'Grocery',
#    'Bakeries',
#    'Automotive',
#    'Fashion']],
#  ['ih8JrT4l5b0MYId6mLyBmQ', 1.0, ['Restaurants', 'Fast Food', 'Mexican']],
#  ['E8duZ9YKVLn_n75lYY3Hyw',
#   4.5,
#   ['Beer',
#    'Wine & Spirits',
#    'Hotels & Travel',
#    'Restaurants',
#    'Wine Tours',
#    'Active Life',
#    'Tours',
#    'Food']],
#  ['89-bwvH5mWWOOb00VTUyFQ',
#   2.5,
#   ['Burgers',
#    'Sports Bars',
#    'American (Traditional)',
#    'Restaurants',
#    'Bars',
#    'Nightlife']],
#  ['2yF0qgsSKHdawSRopnXguA', 3.0, ['Restaurants', 'Burgers', 'Hot Dogs']],
#  ['ILqSwhiIM3ZTtViybcNdRw',
#   3.0,
#   ['Restaurants', 'Middle Eastern', 'Lebanese', 'Fast Food']],
#  ['bRrr2tmhBnE1uGFqmdFUhg', 4.5, ['Restaurants', 'Fast Food', 'Burgers']],
#  ['DwJlGxAJvohbDR_5jV-ERA',
#   2.5,
#   ['Restaurants', 'American (Traditional)', 'French', 'Brasseries']],
#  ['i5j3FrxdR224KIjfv8x2CQ',
#   4.5,
#   ['Breakfast & Brunch',
#    'Restaurants',
#    'Food',
#    'Sandwiches',
#    'Convenience Stores',
#    'Burgers']],
#  ['4P6hZh7aieaZJXShzP3JQg', 3.0, ['Restaurants', 'Mexican']],
#  ['CzmyMl4jnlyQYVaf3YmDYQ',
#   3.0,
#   ['Beer',
#    'Wine & Spirits',
#    'Barbeque',
#    'Arts & Entertainment',
#    'Restaurants',
#    'Food',
#    'Festivals']],
#  ['s-lwOqEEWb_peWh8DhhWUg', 3.5, ['Grocery', 'Food']],
#  ['QfYePNeb1_VVXHOAan5P9A', 3.0, ['Restaurants', 'Korean']],
#  ['Ohy6TtDSeJkVAtIHXP7pMw',
#   3.5,
#   ['Sandwiches', 'American (Traditional)', 'Fast Food', 'Restaurants']],
#  ['TFdLM8R_7Pf1xVeBNKl0hg',
#   4.0,
#   ['Wine Bars',
#    'Breakfast & Brunch',
#    'Bars',
#    'Restaurants',
#    'Diners',
#    'Nightlife',
#    'Mediterranean']],
#  ['lwOuoY4YW1j9zl0RWIIP4A',
#   4.5,
#   ['Food', 'Beer', 'Wine & Spirits', 'Nightlife', 'Wine Bars', 'Bars']],
#  ['Piw03nxAXZF86UYaVrDn1g', 2.5, ['Italian', 'Restaurants']],
#  ['0aKsGxx7XP2TMs_fn_9xVw',
#   4.0,
#   ['Food', 'Chocolatiers & Shops', 'Bakeries', 'Specialty Food', 'Desserts']],
#  ['K7047_-at7Ydi4gl2UuS_w', 3.0, ['Sandwiches', 'Restaurants', 'Fast Food']],
#  ['nepZ1HPAgBqw0TgJWbSgOA',
#   4.5,
#   ['American (Traditional)',
#    'Food',
#    'Barbeque',
#    'Food Trucks',
#    'Restaurants',
#    'Caterers',
#    'Event Planning & Services']],
#  ['VeVjZ8aR_zFEM9jKJuvraw', 3.5, ['Sushi Bars', 'Restaurants']],
#  ['1vBwbEnM65zyxiJZTttMJQ', 2.5, ['Food', 'Grocery']],
#  ['oRAOQy4eyYOswO9zMXF-Uw',
#   3.5,
#   ['Food', 'Coffee & Tea', 'Ice Cream & Frozen Yogurt']],
#  ['arDp3i7B_ULDsbZcYk_57A', 4.0, ['Restaurants', 'Indian']],
#  ['VIsPmeZBMLkgbgw4UqCjUQ',
#   3.0,
#   ['Barbeque', 'Bars', 'Nightlife', 'Restaurants']],
#  ['pr7tK5TICKRsF-6uci08Pw',
#   3.0,
#   ['Vietnamese', 'Asian Fusion', 'Restaurants', 'Thai']],
#  ['MLqSxca8xQvbhI8WqhqHLA', 4.0, ['Italian', 'Restaurants']],
#  ['_W82WbZ-HOiEtr1RWYhM_Q', 4.0, ['Bakeries', 'Food']],
#  ['2z3gnLoBNJPlXswFDESFxQ', 3.5, ['Fast Food', 'Restaurants']],
#  ['kCmUTthR2Z7O7wtUqZGXug', 3.5, ['Restaurants', 'Cafes']],
#  ['Zl6csaZ5HBka3SKBphHXrQ', 3.5, ['Restaurants', 'French']],
#  ['qpm0gm7SdsY2LnvXzQb_uw', 3.5, ['Restaurants', 'Pizza']],
#  ['8FZftD3Y5jQ2R44EDBqhlA',
#   4.5,
#   ['Restaurants', 'Creperies', 'Sandwiches', 'Mediterranean', 'Food']],
#  ['rH39kXAevsXeD-2HsmLj2g',
#   3.5,
#   ['Burgers',
#    'Bars',
#    'American (Traditional)',
#    'Nightlife',
#    'Cocktail Bars',
#    'Restaurants']],
#  ['-cLMYLmmXwomTMMuDHA1Yg',
#   5.0,
#   ['Event Planning & Services', 'Caterers', 'Food Trucks', 'Food']],
#  ['ybjN0J8hmsHKrbYLxRh0jg',
#   3.0,
#   ['Food', 'Coffee & Tea', 'Restaurants', 'Bagels']],
#  ['OgANEur7Bt8YJSd2uSm6yA',
#   1.5,
#   ['Italian', 'Pizza', 'Restaurants', 'Chicken Wings']],
#  ['uhQoPguihcZTo8yp5o2ohw', 2.5, ['Buffets', 'Restaurants']],
#  ['WpkuAJfHSIgjppRC-Wnxgg',
#   2.5,
#   ['Restaurants', 'Bars', 'Nightlife', 'Breakfast & Brunch', 'Italian']],
#  ['t58AtYOZqw9BlDdZHUrZbA', 4.0, ['Indian', 'Restaurants']],
#  ['s4Q0Med8QVVXSrhoAYq-kw', 3.5, ['Mexican', 'Tapas Bars', 'Restaurants']],
#  ['fCqn3Ybfq7pvrbIuWJFmxw', 3.0, ['Grocery', 'Food']],
#  ['WMrsyGlk5nwsKR4rlDLhAQ',
#   4.5,
#   ['Tapas/Small Plates',
#    'Restaurants',
#    'Bars',
#    'Nightlife',
#    'Spanish',
#    'Tapas Bars']],
#  ['MWWOPM-o6lCEQ_SyD9AoaA',
#   4.0,
#   ['Restaurants',
#    'Ice Cream & Frozen Yogurt',
#    'Food',
#    'Juice Bars & Smoothies',
#    'Fast Food']],
#  ['QemTyuZdtyf0u1NeNHPK7A',
#   2.0,
#   ['Cheesesteaks', 'Sandwiches', 'Restaurants']],
#  ['Q6kZqLHy-ikjMW-lBCXnKA',
#   2.0,
#   ['Restaurants',
#    'Tex-Mex',
#    'Imported Food',
#    'Ethnic Food',
#    'Specialty Food',
#    'Food']],
#  ['gTUaz3Wlh8eyQ3s7T-6txw', 2.5, ['Restaurants', 'Chinese']],
#  ['b7pkopqvDr7A7S7hlqp6cw',
#   3.0,
#   ['Caterers',
#    'Specialty Food',
#    'Italian',
#    'Pasta Shops',
#    'Pizza',
#    'Wraps',
#    'Chicken Wings',
#    'Food',
#    'Event Planning & Services',
#    'Restaurants']],
#  ['mZNLVpWuOu75CYOU7sbmTQ', 2.5, ['Restaurants', 'Italian']],
#  ['lBwx8insD-RNa-_lOtA3kA', 2.0, ['Restaurants', 'Indian', 'Pakistani']],
#  ['wIMhHjK6LuGsvpXWR4ntPg', 4.0, ['Mexican', 'Restaurants']],
#  ['IOvDvmIeZh7Tfg1OB_bM6g', 4.5, ['Restaurants', 'Fast Food', 'Turkish']],
#  ['4sMVOl5kgaqBNg-4wRXbWA', 3.5, ['Vietnamese', 'Restaurants']],
#  ['tIjoGxi2r6QvREucvQwZpA',
#   4.5,
#   ['Chicken Wings', 'Soul Food', 'Restaurants', 'Barbeque']],
#  ['ofw8aDSEg1HoQdmCgvLtaQ',
#   4.5,
#   ['Canadian (New)',
#    'Fast Food',
#    'Food',
#    'Do-It-Yourself Food',
#    'Restaurants']],
#  ['ry8bTDAJm-yd7ULXaVuVMA', 4.5, ['Italian', 'Restaurants']],
#  ['lv5Bnqlt93NnvNJ2oNcQ8Q',
#   4.0,
#   ['Tex-Mex',
#    'Mexican',
#    'Caterers',
#    'Restaurants',
#    'Event Planning & Services',
#    'Nightlife',
#    'Bars']],
#  ['OaqbVUL9bYMycpQNYfHBng', 4.0, ['Bakeries', 'Food']]]

# %%
f_b
# Out:
# ['business_id', 'stars', 'categories']
