# %%
from utils.preprocess import JSONLoader
                        
business = 'business.json'
review = 'review.json'
user = 'user.json'
data_dir = 'data/dataset'

# Sample 100 entries from each json files
json_b = JSONLoader(business, data_dir, fields = ['business_id','stars']).sample(100)
json_r = JSONLoader(review, data_dir).sample(100)
json_u = JSONLoader(user, data_dir).sample(100)

# %%
json_b
# Out:
# [['YDf95gJZaq05wvo7hTQbbQ', 2.0],
#  ['mLwM-h2YhXl2NCgdS84_Bw', 4.5],
#  ['v2WhjAB3PIBA8J8VxG3wEg', 4.5],
#  ['CVtCbSB1zUcUWg-9TNGTuQ', 3.0],
#  ['duHFBe87uNSXImQmvBh87Q', 4.5],
#  ['uUEMrhJiL1a1pCA_I1SU7Q', 5.0],
#  ['2eJEUJIP54tex7T9YOcLSw', 5.0],
#  ['fEylCY3UEH8YJ0Xa7lu6lA', 2.5],
#  ['kFtuYklkAIlmYw8RZAieGw', 5.0],
#  ['NqiQdFa93wzUJGo29NbTPQ', 5.0],
#  ['N9BN9ldVl1FNzcB9_eAstw', 4.5],
#  ['6s3z3TlpHOIecuSyPEOp7A', 4.5],
#  ['n33Izvzk_z9_51H6NsQF-A', 2.0],
#  ['m06OZRFTaKKi6U0omfLq4g', 4.5],
#  ['SDMRxmcKPNt1AHPBKqO64Q', 2.0],
#  ['iFEiMJoEqyB9O8OUNSdLzA', 3.0],
#  ['qrAHt4wWRYWj1sEjxq574A', 3.5],
#  ['jqp5TibmgJZVFKHTp3XfqQ', 3.0],
#  ['1cLXGXThDYZ5WK_KpBLtkw', 4.0],
#  ['BmSJ6C7Y9s3tHotRetVbmA', 3.5],
#  ['Av-ODv7-hV12If005Pj6wA', 3.0],
#  ['HmI9nhgOkrXlUr6KZGZZew', 3.0],
#  ['qnpvw-uQyRn9nlClWFK9aA', 2.5],
#  ['igcy3ojJbgbpS8K70gvFQg', 5.0],
#  ['5Ghe0btvM7tXqANnhNB5eg', 5.0],
#  ['vvB8ebrUsjfNqwWjk4G4OQ', 4.0],
#  ['l9ABoPi9j_pH9588tk0-6w', 4.0],
# ...

# %%
json_r
# Out:
# [['VfBHSwC5Vz_pbFluy07i9Q',
#   'cjpdDjZyprfyDG3RlkVG3w',
#   'uYHaNptLzDLoV_JZ_MuzUA',
#   5,
#   '2016-07-12',
# ...

# %%
json_u
# Out:
# [['lsSiIjAKVl-QRxKjRErBeg',
#   'Cin',
#   272,
#   '2010-07-13',
#   ['M19NwFwAXKRZzt8koF11hQ',
#    'QRcMZ8pJJBBZaKubHOoMDQ',
#    'uimsjcHoBnXz1MAKGvB26w',
#    'v325XGF-l9da74ZMWEjyoA',
#    'vP5ajc1oGURsNvCXewsnDw',
#    '9nSutZOliE9Vg4XVGEx1HA',
#    '--2vR0DIsmQ6WfcSzKWigw',
#    'LDJ51sk5SJXovRI2yQZimA',
#    '3R_dB9VQ_D3WPJEw7pmorA',
#    '8drMKNHWavs2g6uf0pLtvg',
#    'wOGfOjBaP-lCS1NW_En2LQ',
#    'AK2-Pvb6E9vgeXWyY4Jxog',
#    'DbUSCSMQwD3eiAre0Ueu8A',
#    'B_2qev6exPELs7ZnO4iljg',
#    'LQALTuDeCRLwR9NOxUWS5A',
#    'kSUU18CH2BRPLK1uUsz1Wg',
#    'M-HINGCHOnaQkKq8WDtRMA',
#    '9lWyDOySHcc6Jiqp2-EPUw',
#    'j2Eu9pE22Rp_DRoSp3KgQg',
#    'neuz9oCcHiW4k-jltcC1BA',
#    'PRQxRp1IFHPBlbXeDwG3mA',
#    't9vCxltuXJ941V8ppWVsVQ',
#    'pYK8JuBylomxLIwwyv0Iyw',
#    'WTLPH3jIWOUTFMpD4o_7Vg',
#    'qAE5pJYa75gRbpC7bgI3Ow',
#    '7OxFrOWLP04hSCGY_g3aUw',
#    'nRdfX_I0CaOq7lJunJMPpA',
#    'W81-CPVrM9c6F8XiNuEUvA',
#    'VaVkC537R46xRNpOucRgvA',
#    'j8YxElKHhbg1ghQDSI1v3Q',
# ...
